# %%
import yfinance as yf
import pandas as pd

# PoC 용 5개 종목 리스트
tickers = ["AAPL", "AMZN", "NVDA", "MSFT", "GOOGL"]

# 수집할 벨류에이션 지표
metrics = [
    "trailingPE",
    "forwardPE",
    "priceToBook",
    "priceToSalesTrailing12Months",
    "enterpriseToRevenue",
    "enterpriseToEbitda",
    "marketCap",
    "enterpriseValue",
    "totalRevenue",
    "netIncomeToCommon",
]

# 데이터 수집
rows = []
for ticker in tickers:
    t = yf.Ticker(ticker)
    info = t.info
    row = {"ticker": ticker}
    for m in metrics:
        row[m] = info.get(m, None)
    rows.append(row)

# DataFrame 생성 및 출력
df_valuation = pd.DataFrame(rows)
print(df_valuation.to_string(index=False))
# Out:
# ticker  trailingPE  forwardPE  priceToBook  priceToSalesTrailing12Months  enterpriseToRevenue  enterpriseToEbitda     marketCap  enterpriseValue  totalRevenue  netIncomeToCommon
#   AAPL   33.071636  25.549927    47.488230                      7.920671                8.109              23.380 3171167502336    3246701674496  400366010368        97294000128
#   AMZN   37.658540  37.658540     8.036086                      3.780884                3.898              20.094 2458758152192    2534768640000  650313007104        65943998464
#   NVDA   57.043690  42.782770    51.269634                     28.944420               28.747              48.379 4298680303616    4269293961216  148514996224        76773998592
#   MSFT   39.689625  34.300335    11.842725                     14.115521               14.202              25.706 3811332063232    3834579779584  270010007552        96635002880
#  GOOGL   20.779510  21.753550     6.500744                      6.359362                6.127              16.157 2361882574848    2275582410752  371399000064       115572998144
